# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os

stds = [0.005, 0.01, 0.015, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.0525, 0.055, 0.0575, 0.06]
path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
output_dir = 'C:\Stuff\Dataset-creation\\notebooks\outputs_ngp_lego_opt_off'
num_iterations = 15000

types = ['position', 'orientation']
for type in types:
    for std in stds:
        command = f'ns-train instant-ngp --data {path_lego} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name lego-{type}-std-{std} ' \
                f'--pipeline.datamanager.camera-optimizer.{type}-noise-std {std} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode off ' \
                f'--pipeline.model.use-appearance-embedding False ' \
                f'--output-dir {output_dir} ' \
                f'blender-data' \
        
        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60  
            

        with open('C:\Stuff\Dataset-creation\\train_ngp_lego_opt_off.txt', 'a') as file:
            text_to_write = f'The command at pos-std={std} and orient-std={std} exited with code: {return_code}, runtime: {running_time_minutes}\n'
            file.write(text_to_write)
            
for std in stds:
    command = f'ns-train instant-ngp --data {path_lego} ' \
            f'--viewer.quit-on-train-completion True ' \
            f'--project-name lego-pos-orient-std-{std} ' \
            f'--pipeline.datamanager.camera-optimizer.{types[0]}-noise-std {std} ' \
            f'--pipeline.datamanager.camera-optimizer.{types[1]}-noise-std {std} ' \
            f'--max-num-iterations {num_iterations} ' \
            f'--pipeline.model.near-plane 2. ' \
            f'--pipeline.model.far-plane 6. ' \
            f'--pipeline.datamanager.camera-optimizer.mode off ' \
            f'--pipeline.model.use-appearance-embedding False ' \
            f'--output-dir {output_dir} ' \
            f'blender-data'

    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  

    with open('C:\Stuff\Dataset-creation\\train_ngp_lego_opt_off.txt', 'a') as file:
        text_to_write = f'The command at pos-std={std} and orient-std={std} exited with code: {return_code}, runtime: {running_time_minutes}\n'
        file.write(text_to_write)

# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os

stds = [0.005, 0.01, 0.015, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.0525, 0.055, 0.0575, 0.06]
path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
output_dir = 'C:\Stuff\Dataset-creation\\notebooks\outputs_ngp_lego_opt_on'
num_iterations = 15000

types = ['position', 'orientation']
for type in types:
    for std in stds:
        command = f'ns-train instant-ngp --data {path_lego} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name lego-{type}-std-{std} ' \
                f'--pipeline.datamanager.camera-optimizer.{type}-noise-std {std} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode SO3xR3 ' \
                f'--pipeline.model.use-appearance-embedding False ' \
                f'--output-dir {output_dir} ' \
                f'blender-data' \

        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60  
            

        with open('C:\Stuff\Dataset-creation\\train_ngp_lego_opt_on.txt', 'a') as file:
            text_to_write = f'The command at pos-std={std} and orient-std={std} exited with code: {return_code}, runtime: {running_time_minutes}\n'
            file.write(text_to_write)

for std in stds:
    command = f'ns-train instant-ngp --data {path_lego} ' \
            f'--viewer.quit-on-train-completion True ' \
            f'--project-name lego-pos-orient-std-{std} ' \
            f'--pipeline.datamanager.camera-optimizer.{types[0]}-noise-std {std} ' \
            f'--pipeline.datamanager.camera-optimizer.{types[1]}-noise-std {std} ' \
            f'--max-num-iterations {num_iterations} ' \
            f'--pipeline.model.near-plane 2. ' \
            f'--pipeline.model.far-plane 6. ' \
            f'--pipeline.datamanager.camera-optimizer.mode SO3xR3 ' \
            f'--pipeline.model.use-appearance-embedding False ' \
            f'--output-dir {output_dir} ' \
            f'blender-data'

    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  

    with open('C:\Stuff\Dataset-creation\\train_ngp_lego_opt_on.txt', 'a') as file:
        text_to_write = f'The command at pos-std={std} and orient-std={std} exited with code: {return_code}, runtime: {running_time_minutes}\n'
        file.write(text_to_write)
