# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os 

pathes_datasets=[
'C:\Stuff\Dataset-creation\data_lego\lego-saturation',
'C:\Stuff\Dataset-creation\data_lego\lego-range',]

path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
num_iterations = 15000

for path_dataset in pathes_datasets:
    for folder in os.listdir(path_dataset):
        path_sub_dataset = os.path.join(path_dataset, folder)
        command = f'ns-train nerfacto --data {path_sub_dataset} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name {folder} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode off ' \
                f'--pipeline.model.use-average-appearance-embedding False ' \
                f'--output-dir outputs-nerfacto-lego-opt-off-satur-range ' \
                f'blender-data ' \

        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60  

        filepath = r'C:\Stuff\Dataset-creation\\missing_runs.txt'
        if not os.path.exists(filepath):
            open(filepath, 'a').close()

        with open(filepath, 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
            file.write(text_to_write)

# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os 

pathes_datasets=[
'C:\Stuff\Dataset-creation\data_lego\lego-saturation',
'C:\Stuff\Dataset-creation\data_lego\lego-range',]

path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
num_iterations = 15000

for path_dataset in pathes_datasets:
    for folder in os.listdir(path_dataset):
        path_sub_dataset = os.path.join(path_dataset, folder)
        command = f'ns-train nerfacto --data {path_sub_dataset} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name {folder} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode SO3xR3 ' \
                f'--pipeline.model.use-average-appearance-embedding False ' \
                f'--output-dir outputs-nerfacto-lego-opt-on-satur-range ' \
                f'blender-data ' \

        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60  

        filepath = r'C:\Stuff\Dataset-creation\\missing_runs.txt'
        if not os.path.exists(filepath):
            open(filepath, 'a').close()

        with open(filepath, 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
            file.write(text_to_write)

# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os 

pathes_datasets=[
'C:\Stuff\Dataset-creation\data_lego\lego-saturation',
'C:\Stuff\Dataset-creation\data_lego\lego-range',]

path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
num_iterations = 15000

for path_dataset in pathes_datasets:
    for folder in os.listdir(path_dataset):
        path_sub_dataset = os.path.join(path_dataset, folder)
        command = f'ns-train instant-ngp --data {path_sub_dataset} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name {folder} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode off ' \
                f'--output-dir outputs-ngp-lego-opt-off-satur-range ' \
                f'blender-data ' \
        
        print(command)
        # start_time = time.time() 
        # process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        # process.wait() 
        # end_time = time.time()  

        # return_code = process.returncode
        # running_time = end_time - start_time  
        # running_time_minutes = running_time / 60  

        # filepath = r'C:\Stuff\Dataset-creation\\missing_runs.txt'
        # if not os.path.exists(filepath):
        #     open(filepath, 'a').close()

        # with open(filepath, 'a') as file:
        #     text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
        #     file.write(text_to_write)
# Out:
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.1 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.1 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.2 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.2 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.3 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.3 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.4 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.4 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.5 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.5 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.6 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.6 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.7 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.7 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.8 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.8 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.9 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.9 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-1.0 --viewer.quit-on-train-completion True --project-name lego-saturation-std-1.0 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-10 --viewer.quit-on-train-completion True --project-name lego-range-10 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-100 --viewer.quit-on-train-completion True --project-name lego-range-100 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-20 --viewer.quit-on-train-completion True --project-name lego-range-20 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-30 --viewer.quit-on-train-completion True --project-name lego-range-30 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-40 --viewer.quit-on-train-completion True --project-name lego-range-40 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-50 --viewer.quit-on-train-completion True --project-name lego-range-50 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-60 --viewer.quit-on-train-completion True --project-name lego-range-60 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-70 --viewer.quit-on-train-completion True --project-name lego-range-70 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-80 --viewer.quit-on-train-completion True --project-name lego-range-80 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-90 --viewer.quit-on-train-completion True --project-name lego-range-90 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --output-dir outputs-ngp-lego-opt-off-satur-range blender-data

# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os 

pathes_datasets=[
'C:\Stuff\Dataset-creation\data_lego\lego-saturation',
'C:\Stuff\Dataset-creation\data_lego\lego-range',]

path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
num_iterations = 15000

for path_dataset in pathes_datasets:
    for folder in os.listdir(path_dataset):
        path_sub_dataset = os.path.join(path_dataset, folder)
        command = f'ns-train instant-ngp --data {path_sub_dataset} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name {folder} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode SO3xR3 ' \
                f'--output-dir outputs-ngp-lego-opt-on-satur-range ' \
                f'blender-data ' \
        
        print(command)
        # start_time = time.time() 
        # process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        # process.wait() 
        # end_time = time.time()  

        # return_code = process.returncode
        # running_time = end_time - start_time  
        # running_time_minutes = running_time / 60  

        # filepath = r'C:\Stuff\Dataset-creation\\missing_runs.txt'
        # if not os.path.exists(filepath):
        #     open(filepath, 'a').close()

        # with open(filepath, 'a') as file:
        #     text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
        #     file.write(text_to_write)
# Out:
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.1 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.1 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.2 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.2 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.3 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.3 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.4 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.4 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.5 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.5 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.6 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.6 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.7 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.7 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.8 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.8 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-0.9 --viewer.quit-on-train-completion True --project-name lego-saturation-std-0.9 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-saturation\lego-saturation-std-1.0 --viewer.quit-on-train-completion True --project-name lego-saturation-std-1.0 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-10 --viewer.quit-on-train-completion True --project-name lego-range-10 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-100 --viewer.quit-on-train-completion True --project-name lego-range-100 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-20 --viewer.quit-on-train-completion True --project-name lego-range-20 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-30 --viewer.quit-on-train-completion True --project-name lego-range-30 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-40 --viewer.quit-on-train-completion True --project-name lego-range-40 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-50 --viewer.quit-on-train-completion True --project-name lego-range-50 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-60 --viewer.quit-on-train-completion True --project-name lego-range-60 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-70 --viewer.quit-on-train-completion True --project-name lego-range-70 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-80 --viewer.quit-on-train-completion True --project-name lego-range-80 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-range\lego-range-90 --viewer.quit-on-train-completion True --project-name lego-range-90 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --output-dir outputs-ngp-lego-opt-on-satur-range blender-data

# %%
import re
import subprocess
import os
import time  # Import the time module

def extract_project_name_from_yaml(file_path):
    with open(file_path, 'r') as file:
        yaml_content = file.read()
        project_name_start = yaml_content.find('project_name:') + len('project_name:')
        project_name_end = yaml_content.find('\n', project_name_start)
        project_name_value = yaml_content[project_name_start:project_name_end].strip()

    return project_name_value

# %%
MODEL_TYPE = 'instant-ngp'
f1= r'outputs-nerfacto-lego-opt-off-satur-range'
f2= r'outputs-nerfacto-lego-opt-on-satur-range'
f3= r'outputs-ngp-lego-opt-off-satur-range'
f4= r'outputs-ngp-lego-opt-on-satur-range'
folders = [f1,f2,f3,f4]
PATH_OUTPUTS = r'C:\Stuff\Dataset-creation\notebooks'
i = 0

for folder in folders:
    if 'nerfacto' in folder:
        model_type = 'nerfacto'
    else:
        model_type = 'instant-ngp'
    path_outputs = os.path.join(PATH_OUTPUTS, folder)
    for degradation_type in os.listdir(path_outputs)[:]:
        runs = os.path.join(path_outputs, degradation_type, model_type)
        if len(os.listdir(runs)) > 1:
        # for i, run in enumerate(os.listdir(runs)):
            for run in os.listdir(runs)[:5]:
                run_config_path = os.path.join(runs, run, 'config.yml') 
                project_name = extract_project_name_from_yaml(run_config_path)
                path_render = os.path.join(f'C:\\Stuff\\Dataset-creation\\renders_{folder}', run)
            
                base_command =   f'ns-eval --load-config={run_config_path} ' \
                                f'--output-path={folder}_{project_name}.json '             
                render_command = f'--render-output-path={path_render} '
                command = base_command + render_command
                
                start_time = time.time() 
                process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                process.wait() 
                end_time = time.time()  

                return_code = process.returncode
                running_time = end_time - start_time  
                running_time_minutes = running_time / 60                

                with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
                    text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
                    file.write(text_to_write)
