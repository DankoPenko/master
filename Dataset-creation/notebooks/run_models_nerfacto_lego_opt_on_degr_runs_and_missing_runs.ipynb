# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os

# %%
pathes_datasets=[
# 'C:\Stuff\Dataset-creation\data_lego\lego-noise',
'C:\Stuff\Dataset-creation\data_lego\lego-pns-noise',]
# 'C:\Stuff\Dataset-creation\data_lego\lego-sparce',
# 'C:\Stuff\Dataset-creation\data_lego\lego-gamma',
# 'C:\Stuff\Dataset-creation\data\lego-range',
# 'C:\Stuff\Dataset-creation\data_lego\lego-saturation',]

path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
num_iterations = 15000


for path_dataset in pathes_datasets:
    for folder in os.listdir(path_dataset):
        path_sub_dataset = os.path.join(path_dataset, folder)
        command = f'ns-train nerfacto --data {path_sub_dataset} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name {folder} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode SO3xR3 ' \
                f'--pipeline.model.use-average-appearance-embedding False ' \
                f'blender-data ' \
        
        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60  

        with open('C:\Stuff\Dataset-creation\\nerfacto_lego_opt_on_degr_runs.txt', 'a') as file:
            text_to_write = f'The command at {folder} exited with code: {return_code}, {running_time_minutes}\n'
            file.write(text_to_write)

# %%
c1 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.2 --output-dir outputs_missing_ngp_opt_off --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.2 --max-num-iterations 15000 nerfstudio-data --eval-mode filename'
c2 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.3 --output-dir outputs_missing_ngp_opt_off --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.3 --max-num-iterations 15000 nerfstudio-data --eval-mode filename'
c3 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.7 --output-dir outputs_missing_ngp_opt_off --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.7 --max-num-iterations 15000 nerfstudio-data --eval-mode filename'
c4 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-gamma\stump-gamma-40 --output-dir outputs_missing_ngp_opt_off --viewer.quit-on-train-completion True --project-name stump-gamma-40 --max-num-iterations 15000 nerfstudio-data --eval-mode filename'
commands = [c1,c2,c3,c4]

for command in commands:
    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  

    with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
        text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
        file.write(text_to_write)

# %%
#unluck unsuc
c3 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.7 --output-dir outputs_missing_ngp_opt_off --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.7 --max-num-iterations 15000 nerfstudio-data --eval-mode filename'
commands = [c3]

for command in commands:
    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  

    with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
        text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
        file.write(text_to_write)

# %%
eval_command = r'ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_missing_ngp_opt_off\stump-saturation-std-0\instant-ngp\2024-03-17_035102\config.yml --output-path=ngp_opt_off_stump-saturation-std-0.7.json --render-output-path=C:\Stuff\Dataset-creation\renders_missing_ngp_opt_off\2024-03-17_035102'
start_time = time.time() 
process = subprocess.Popen(eval_command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
process.wait() 
end_time = time.time()  

return_code = process.returncode
running_time = end_time - start_time  
running_time_minutes = running_time / 60  

with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
    text_to_write = f'The eval_command at {eval_command} exited with code: {return_code}, {running_time_minutes}\n'
    file.write(text_to_write)

# %%
c1 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-position-std-0.035 --pipeline.datamanager.camera-optimizer.position-noise-std 0.035 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3 nerfstudio-data --eval-mode filename'
c2 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-position-std-0.04 --pipeline.datamanager.camera-optimizer.position-noise-std 0.04 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3 nerfstudio-data --eval-mode filename'
c3 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-position-std-0.045 --pipeline.datamanager.camera-optimizer.position-noise-std 0.045 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3 nerfstudio-data --eval-mode filename'
c4 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-position-std-0.045 --pipeline.datamanager.camera-optimizer.position-noise-std 0.045 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3 nerfstudio-data --eval-mode filename'
c5 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-orientation-std-0.06 --pipeline.datamanager.camera-optimizer.orientation-noise-std 0.06 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3 nerfstudio-data --eval-mode filename'
c6 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-pns-noise\stump-pns-green-noise-percent-20 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-pns-green-noise-percent-20 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode   nerfstudio-data --eval-mode filename'
c7 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.6 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.6 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode   nerfstudio-data --eval-mode filename'
c8 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.9 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.9 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode   nerfstudio-data --eval-mode filename'
c9 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-sparce\stump-every-2 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-every-2 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode   nerfstudio-data --eval-mode filename'

commands = [c1,c2,c3,c4,c5,c6,c7,c8,c9]

for command in commands:
    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  

    with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
        text_to_write = f'The command at {folder} exited with code: {return_code}, {running_time_minutes}\n'
        file.write(text_to_write)

# %%
c6 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-pns-noise\stump-pns-green-noise-percent-20 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-pns-green-noise-percent-20 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3   nerfstudio-data --eval-mode filename'
c7 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.6 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.6 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3   nerfstudio-data --eval-mode filename'
c8 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-saturation\stump-saturation-std-0.9 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-saturation-std-0.9 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3   nerfstudio-data --eval-mode filename'
c9 = 'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data\stump-sparce\stump-every-2 --output-dir outputs_missing_ngp_opt_on --viewer.quit-on-train-completion True --project-name stump-every-2 --max-num-iterations 15000 --pipeline.datamanager.camera-optimizer.mode SO3xR3   nerfstudio-data --eval-mode filename'
commands = [c6,c7,c8,c9]

for command in commands:
    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  

    with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
        text_to_write = f'The command at {folder} exited with code: {return_code}, {running_time_minutes}\n'
        file.write(text_to_write)

# %%
#### TODO
#####
########
###########
# The command at ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_missing_ngp_opt_off\stump-saturation-std-0\instant-ngp\2024-03-17_031655\config.yml --output-path=ngp_opt_off_stump-saturation-std-0.7.json --render-output-path=C:\Stuff\Dataset-creation\renders_missing_ngp_opt_off\2024-03-17_031655  exited with code: 1, 1.5011688510576884 #

# %%
import time
import os
import re
import subprocess
import os

def extract_project_name_from_yaml(file_path):
    with open(file_path, 'r') as file:
        yaml_content = file.read()
        project_name_start = yaml_content.find('project_name:') + len('project_name:')
        project_name_end = yaml_content.find('\n', project_name_start)
        project_name_value = yaml_content[project_name_start:project_name_end].strip()

    return project_name_value

model_type = 'instant-ngp'
path_outputs = r'C:\Stuff\Dataset-creation\notebooks\outputs_missing_ngp_opt_off'
i = 0
# for i, degradation_type in enumerate(os.listdir(path_outputs)[1:]):
for degradation_type in os.listdir(path_outputs):
    runs = os.path.join(path_outputs, degradation_type, model_type)
    # for i, run in enumerate(os.listdir(runs)):
    for run in os.listdir(runs):
        run_config_path = os.path.join(runs, run, 'config.yml') 
        project_name = extract_project_name_from_yaml(run_config_path)
        path_render = os.path.join('C:\\Stuff\\Dataset-creation\\renders_missing_ngp_opt_off', run)
        
        base_command =   f'ns-eval --load-config={run_config_path} ' \
                        f'--output-path=ngp_opt_off_{project_name}.json '             
        render_command = f'--render-output-path={path_render} '
        command = base_command + render_command
        
        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60                

        with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
            file.write(text_to_write)

# %%
model_type = 'instant-ngp'
path_outputs = r'C:\Stuff\Dataset-creation\notebooks\outputs_missing_ngp_opt_on'
i = 0
# for i, degradation_type in enumerate(os.listdir(path_outputs)[1:]):
for degradation_type in os.listdir(path_outputs):
    runs = os.path.join(path_outputs, degradation_type, model_type)
    # for i, run in enumerate(os.listdir(runs)):
    for run in os.listdir(runs):
        run_config_path = os.path.join(runs, run, 'config.yml') 
        project_name = extract_project_name_from_yaml(run_config_path)
        path_render = os.path.join('C:\\Stuff\\Dataset-creation\\renders_missing_ngp_opt_on', run)
        
        base_command =   f'ns-eval --load-config={run_config_path} ' \
                        f'--output-path=ngp_opt_on_{project_name}.json '             
        render_command = f'--render-output-path={path_render} '
        command = base_command + render_command
        
        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60                

        with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
            file.write(text_to_write)

# %%
#MISSING RUNS, SAME AS CELL ABOVE BUT FOR UNSUC RUNS (WITH CODE 1 IN MISSING_RUNS.TXT)
model_type = 'instant-ngp'
path_outputs = r'C:\Stuff\Dataset-creation\notebooks\outputs_missing_ngp_opt_on'
i = 0
for i, degradation_type in enumerate(os.listdir(path_outputs)[1:]):
    runs = os.path.join(path_outputs, degradation_type, model_type)
    for run in os.listdir(runs):
        run_config_path = os.path.join(runs, run, 'config.yml') 
        project_name = extract_project_name_from_yaml(run_config_path)
        path_render = os.path.join('C:\\Stuff\\Dataset-creation\\renders_missing_ngp_opt_on', run)
        
        base_command =   f'ns-eval --load-config={run_config_path} ' \
                        f'--output-path=ngp_opt_on_{project_name}.json '             
        render_command = f'--render-output-path={path_render} '
        command = base_command + render_command
        
        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60                

        with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
            file.write(text_to_write)

# %%
model_type = 'nerfacto'
path_outputs = r'C:\Stuff\Dataset-creation\notebooks\outputs'
i = 0
# for i, degradation_type in enumerate(os.listdir(path_outputs)[1:]):
for degradation_type in os.listdir(path_outputs):
    runs = os.path.join(path_outputs, degradation_type, model_type)
    # for i, run in enumerate(os.listdir(runs)):
    for run in os.listdir(runs):
        run_config_path = os.path.join(runs, run, 'config.yml') 
        project_name = extract_project_name_from_yaml(run_config_path)
        path_render = os.path.join('C:\\Stuff\\Dataset-creation\\renders_missing_nerfacto_lego_opt_off_pns', run)
        
        base_command =   f'ns-eval --load-config={run_config_path} ' \
                        f'--output-path=nerfacto_opt_off_{project_name}.json '             
        render_command = f'--render-output-path={path_render} '
        command = base_command + render_command
        
        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60                

        with open('C:\Stuff\Dataset-creation\\missing_runs.txt', 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}, {running_time_minutes}\n'
            file.write(text_to_write)
