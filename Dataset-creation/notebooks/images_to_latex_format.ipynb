# %%
import os
path = 'C:\Stuff\Dataset-creation\\rendered_images_for_latex'
filenames = os.listdir(path)
# filenames = [i for i in filenames if 'only' in i]

latex_code = r"\begin{figure}[h]"
for i in range(0, len(filenames)):
    # filename = f"pos_{pos:03d}"
    file1 = filenames[i]
    pos = 123
    # caption = f"pos-{pos / 100:.2f}"
    caption = 321
    subfigure_code = f"""\\begin{{subfigure}}{{0.16\\textwidth}}
      \\includegraphics[width=\\linewidth]{{images/comparison_new_format/{file1}}}
      \\caption{{{caption}}}
      \\label{{fig:{file1}}}
    \\end{{subfigure}}\\hfil % <-- added
    """
    
    latex_code += subfigure_code
latex_code += r"\end{figure}"

print(latex_code)
# Out:
# \begin{figure}[h]\begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.03-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.03-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.03-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.03-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.05-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.05-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.05-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.05-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.0525-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.0525-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.0525-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.0525-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.055-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.055-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.055-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.055-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.0575-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.0575-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.0575-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.0575-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.06-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.06-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-orient-std-0.06-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-orient-std-0.06-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.03-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.03-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.03-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.03-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.05-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.05-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.05-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.05-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.0525-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.0525-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.0525-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.0525-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.055-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.055-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.055-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.055-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.0575-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.0575-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.0575-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.0575-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.06-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.06-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-orient-std-0.06-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-orient-std-0.06-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.03-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.03-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.03-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.03-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.05-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.05-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.05-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.05-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.0525-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.0525-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.0525-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.0525-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.055-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.055-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.055-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.055-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.0575-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.0575-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.0575-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.0575-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.06-psnr-crop_degrated_000007-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.06-psnr-crop_degrated_000007-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \begin{subfigure}{0.16\textwidth}
#       \includegraphics[width=\linewidth]{images/comparison_new_format/stump-pos-std-0.06-psnr-crop_degrated_000012-img.jpg}
#       \caption{321}
#       \label{fig:stump-pos-std-0.06-psnr-crop_degrated_000012-img.jpg}
#     \end{subfigure}\hfil % <-- added
#     \end{figure}
