# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os 

pathes_datasets=[
'C:\Stuff\Dataset-creation\data_lego\lego-noise',
'C:\Stuff\Dataset-creation\data_lego\lego-pns-noise',
'C:\Stuff\Dataset-creation\data_lego\lego-sparce',
'C:\Stuff\Dataset-creation\data_lego\lego-gamma',]
# 'C:\Stuff\Dataset-creation\data\lego-range',
# 'C:\Stuff\Dataset-creation\data_lego\lego-saturation',]

path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
output_dir = r'C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr'
num_iterations = 15000


for path_dataset in pathes_datasets:
    for folder in os.listdir(path_dataset):
        path_sub_dataset = os.path.join(path_dataset, folder)
        command = f'ns-train instant-ngp --data {path_sub_dataset} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name {folder} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode off ' \
                f'--pipeline.model.use-appearance-embedding False ' \
                f'--output-dir {output_dir} ' \
                f'blender-data ' \
                
        if 'pns-blue-noise-percent-5' in command:
            print(command)

        # start_time = time.time() 
        # process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        # process.wait() 
        # end_time = time.time()  

        # return_code = process.returncode
        # running_time = end_time - start_time  
        # running_time_minutes = running_time / 60  

        # filepath = r'C:\Stuff\Dataset-creation\\ngp_lego_opt_off_degr_runs.txt'
        # if not os.path.exists(filepath):
        #     open(filepath, 'a').close()

        # with open(filepath, 'a') as file:
        #     text_to_write = f'The command at {folder} exited with code: {return_code}, {running_time_minutes}\n'
        #     file.write(text_to_write)
# Out:
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-pns-noise\lego-pns-blue-noise-percent-5 --viewer.quit-on-train-completion True --project-name lego-pns-blue-noise-percent-5 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --pipeline.model.use-appearance-embedding False --output-dir C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr blender-data

# %%
import re
import subprocess
import os
import time  # Import the time module

def extract_project_name_from_yaml(file_path):
    with open(file_path, 'r') as file:
        yaml_content = file.read()
        project_name_start = yaml_content.find('project_name:') + len('project_name:')
        project_name_end = yaml_content.find('\n', project_name_start)
        project_name_value = yaml_content[project_name_start:project_name_end].strip()

    return project_name_value

# %%
MODEL_TYPE = 'instant-ngp'
output_dir = r'C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr'
PATH_OUTPUTS = output_dir
i = 0
for degradation_type in os.listdir(PATH_OUTPUTS)[:]:
    runs = os.path.join(PATH_OUTPUTS, degradation_type, MODEL_TYPE)
    for run in os.listdir(runs)[:]:
        run_config_path = os.path.join(runs, run, 'config.yml') 
        project_name = extract_project_name_from_yaml(run_config_path)
        path_render = os.path.join('C:\\Stuff\\Dataset-creation\\renders_ngp_lego_opt_off_degr_runs', run)
        
        base_command =   f'ns-eval --load-config={run_config_path} ' \
                        f'--output-path=ngp_lego_opt_off_degr_runs_{project_name}.json '             
        render_command = f'--render-output-path={path_render} '
        command = base_command + render_command


        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60  
            

        with open('C:\Stuff\Dataset-creation\\ngp_lego_opt_off_degr_runs.txt', 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}; runtime: {running_time_minutes:.2f} minutes.\n'
            file.write(text_to_write)
# Out:
# ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr\lego-pns-blue-noise-percent-5\instant-ngp\2024-03-25_025901\config.yml --output-path=ngp_lego_opt_off_degr_runs_lego-pns-blue-noise-percent-5.json --render-output-path=C:\Stuff\Dataset-creation\renders_ngp_lego_opt_off_degr_runs\2024-03-25_025901

# %%
import time
import shutil
import subprocess
from pathlib import Path
import numpy as np
import os 

pathes_datasets=[
'C:\Stuff\Dataset-creation\data_lego\lego-noise',
'C:\Stuff\Dataset-creation\data_lego\lego-pns-noise',
'C:\Stuff\Dataset-creation\data_lego\lego-sparce',
'C:\Stuff\Dataset-creation\data_lego\lego-gamma',]
# 'C:\Stuff\Dataset-creation\data\lego-range',
# 'C:\Stuff\Dataset-creation\data_lego\lego-saturation',]

path_lego = 'C:\Stuff\Dataset-creation\data_lego\lego'
output_dir = r'C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_on_degr'
num_iterations = 15000


for path_dataset in pathes_datasets:
    for folder in os.listdir(path_dataset):
        path_sub_dataset = os.path.join(path_dataset, folder)
        command = f'ns-train instant-ngp --data {path_sub_dataset} ' \
                f'--viewer.quit-on-train-completion True ' \
                f'--project-name {folder} ' \
                f'--max-num-iterations {num_iterations} ' \
                f'--pipeline.model.near-plane 2. ' \
                f'--pipeline.model.far-plane 6. ' \
                f'--pipeline.datamanager.camera-optimizer.mode SO3xR3 ' \
                f'--pipeline.model.use-appearance-embedding False ' \
                f'--output-dir {output_dir} ' \
                f'blender-data ' \

        if 'pns-green-noise-percent-15' in command:
            print(command)
        # start_time = time.time() 
        # process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        # process.wait() 
        # end_time = time.time()  

        # return_code = process.returncode
        # running_time = end_time - start_time  
        # running_time_minutes = running_time / 60  

        # filepath = r'C:\Stuff\Dataset-creation\\ngp_lego_opt_on_degr_runs.txt'
        # if not os.path.exists(filepath):
        #     open(filepath, 'a').close()

        # with open(filepath, 'a') as file:
        #     text_to_write = f'The command at {folder} exited with code: {return_code}, {running_time_minutes}\n'
        #     file.write(text_to_write)
# Out:
# ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-pns-noise\lego-pns-green-noise-percent-15 --viewer.quit-on-train-completion True --project-name lego-pns-green-noise-percent-15 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --pipeline.model.use-appearance-embedding False --output-dir C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_on_degr blender-data

# %%
MODEL_TYPE = 'instant-ngp'
PATH_OUTPUTS = output_dir
i = 0
for degradation_type in os.listdir(PATH_OUTPUTS)[:]:
    runs = os.path.join(PATH_OUTPUTS, degradation_type, MODEL_TYPE)
    for run in os.listdir(runs)[:]:
        run_config_path = os.path.join(runs, run, 'config.yml') 
        project_name = extract_project_name_from_yaml(run_config_path)
        print(project_name)
        path_render = os.path.join('C:\\Stuff\\Dataset-creation\\renders_ngp_lego_opt_on_degr_runs', run)
        
        base_command =   f'ns-eval --load-config={run_config_path} ' \
                        f'--output-path=ngp_lego_opt_on_degr_runs_{project_name}.json '             
        render_command = f'--render-output-path={path_render} '
        command = base_command + render_command
        print(command)

        start_time = time.time() 
        process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        process.wait() 
        end_time = time.time()  

        return_code = process.returncode
        running_time = end_time - start_time  
        running_time_minutes = running_time / 60  
            

        with open('C:\Stuff\Dataset-creation\\ngp_lego_opt_on_degr_runs.txt', 'a') as file:
            text_to_write = f'The command at {command} exited with code: {return_code}; runtime: {running_time_minutes:.2f} minutes.\n'
            file.write(text_to_write)
# Out:
# lego-every-2
# ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_on_degr\lego-every-2\instant-ngp\2024-03-25_122819\config.yml --output-path=ngp_lego_opt_on_degr_runs_lego-every-2.json --render-output-path=C:\Stuff\Dataset-creation\renders_ngp_lego_opt_on_degr_runs\2024-03-25_122819
# lego-every-3
# ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_on_degr\lego-every-3\instant-ngp\2024-03-25_123552\config.yml --output-path=ngp_lego_opt_on_degr_runs_lego-every-3.json --render-output-path=C:\Stuff\Dataset-creation\renders_ngp_lego_opt_on_degr_runs\2024-03-25_123552
# lego-every-4
# ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_on_degr\lego-every-4\instant-ngp\2024-03-25_124335\config.yml --output-path=ngp_lego_opt_on_degr_runs_lego-every-4.json --render-output-path=C:\Stuff\Dataset-creation\renders_ngp_lego_opt_on_degr_runs\2024-03-25_124335
# lego-every-5
# ...

# %%
c1 = r'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-noise\lego-noise-std-16 --viewer.quit-on-train-completion True --project-name lego-noise-std-16 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --pipeline.model.use-appearance-embedding False --output-dir C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr blender-data'
c2 = r'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-pns-noise\lego-pns-blue-noise-percent-5 --viewer.quit-on-train-completion True --project-name lego-pns-blue-noise-percent-5 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode off --pipeline.model.use-appearance-embedding False --output-dir C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr blender-data'
c3 = r'ns-train instant-ngp --data C:\Stuff\Dataset-creation\data_lego\lego-pns-noise\lego-pns-green-noise-percent-15 --viewer.quit-on-train-completion True --project-name lego-pns-green-noise-percent-15 --max-num-iterations 15000 --pipeline.model.near-plane 2. --pipeline.model.far-plane 6. --pipeline.datamanager.camera-optimizer.mode SO3xR3 --pipeline.model.use-appearance-embedding False --output-dir C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_on_degr blender-data'
cmds = [c1, c2, c3]

for command in cmds:
    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  
        

    with open('C:\Stuff\Dataset-creation\\ngp_lego_opt_on_degr_runs.txt', 'a') as file:
        text_to_write = f'The command at {command} exited with code: {return_code}; runtime: {running_time_minutes:.2f} minutes.\n'
        file.write(text_to_write)

# %%
# c1 =  r'ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr\lego-pns-blue-noise-percent-5\instant-ngp\2024-03-31_183516\config.yml --output-path=ngp_lego_opt_off_degr_runs_lego-pns-blue-noise-percent-5.json --render-output-path=C:\Stuff\Dataset-creation\renders_ngp_lego_opt_off_degr_runs\2024-03-31_183516'
c2 = r'ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_off_degr\lego-noise-std-16\instant-ngp\2024-03-31_182748\config.yml --output-path=ngp_lego_opt_off_degr_runs_lego-noise-std-16.json --render-output-path=C:\Stuff\Dataset-creation\renders_ngp_lego_opt_off_degr_runs\2024-03-31_182748'
c3 = r'ns-eval --load-config=C:\Stuff\Dataset-creation\notebooks\outputs_ngp_lego_opt_on_degr\lego-pns-green-noise-percent-15\instant-ngp\2024-03-31_184303\config.yml  --output-path=ngp_lego_opt_on_degr_runs_lego-pns-green-noise-percent-15.json --render-output-path=C:\Stuff\Dataset-creation\renders_ngp_lego_opt_on_degr_runs\2024-03-31_184303'

cmds = [c2, c3]
for command in cmds:
    start_time = time.time() 
    process = subprocess.Popen(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    process.wait() 
    end_time = time.time()  

    return_code = process.returncode
    running_time = end_time - start_time  
    running_time_minutes = running_time / 60  
        

    with open('C:\Stuff\Dataset-creation\\ngp_lego_opt_on_degr_runs.txt', 'a') as file:
        text_to_write = f'The command at {command} exited with code: {return_code}; runtime: {running_time_minutes:.2f} minutes.\n'
        file.write(text_to_write)
