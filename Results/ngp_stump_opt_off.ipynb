# %%
from torchmetrics.functional import structural_similarity_index_measure
from torchmetrics.image import PeakSignalNoiseRatio
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity
import re 
import json 
import os
from PIL import Image, ImageDraw, ImageFont
from torchvision.transforms import ToTensor
import numpy as np
import matplotlib.pyplot as plt 

types = ['benchmark', 'every', 'gamma', 'noise-std', 'orientation', 'blue-noise', 'green-noise', 'red-noise', 'pos-orient', 'position', 'range', 'saturation']
types_dict = {type: {} for type in types}

psnr_metric = PeakSignalNoiseRatio(data_range=1.0)
lpips_metric = LearnedPerceptualImagePatchSimilarity()
ssim_metric = structural_similarity_index_measure

def get_timestamp(path):
    f = open(path)
    data =  json.load(f)
    ckpt_path = data['checkpoint']
    pattern = r'\d{4}-\d{2}-\d{2}_\d{6}'
    match = re.search(pattern, ckpt_path)
    timestamp = match.group()
    return timestamp

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)

# %%
PATH_ORIGINAL_IMAGES = "C:\Stuff\Results\stump_original"
PATH_RENDERS = r"C:\Stuff\Results\renders\renders_ngp_stump_opt_off"

for folder_path in os.listdir(PATH_RENDERS)[:]:
    for filename in os.listdir(os.path.join(PATH_RENDERS, folder_path)):
        if filename.lower().endswith('img.jpg') and 'crop' not in filename:
            file_path = os.path.join(PATH_RENDERS, folder_path, filename)
            original_image = Image.open(file_path)
            original_width, original_height = original_image.size
            left = original_width / 2  # Start from the middle of the image to get the right half
            top = 0  # Start from the top edge of the image
            right = original_width  # Extend to the right edge of the image
            bottom = original_height  # Extend to the bottom edge of the image
            cropped_image = original_image.crop((left, top, right, bottom))
            new_filename = f"crop_degrated_{filename}"
            new_file_path = os.path.join(PATH_RENDERS, folder_path, new_filename)
            cropped_image.save(new_file_path)
            original_image.close()

print("Cropping completed.")
# Out:
# Cropping completed.

# %%
import os
jsons_folder = "C:\Stuff\Results\jsons\jsons_ngp_stump_opt_off"
renders_folder = r"C:\Stuff\Results\renders\renders_stump_ngp_opt_off"
# renders_folde2 = r'C:\Stuff\Results\unknown_lego_renders'

for file in os.listdir(jsons_folder):
    if file.endswith('.json'):
        json_path = os.path.join(jsons_folder, file)
        timestamp = get_timestamp(json_path)
        run_path = os.path.join(renders_folder, timestamp)
        run_path2 = os.path.join(renders_folder, timestamp)
        if os.path.isdir(run_path): #or os.path.isdir(run_path2):
            print(f"Folder with name {timestamp} exists in renders_folder., {len(os.listdir(run_path))} images found.")
        else:
            print(f"Folder with name {timestamp} does not exist in renders_folder.")
# Out:
# Folder with name 2024-03-19_163127 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_151315 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_152158 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_153050 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_153830 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_154719 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_155435 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_160152 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_140235 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_141207 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_142139 exists in renders_folder., 68 images found.
# Folder with name 2024-03-17_143415 exists in renders_folder., 68 images found.
# Folder with name 2024-03-17_142630 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_144506 exists in renders_folder., 68 images found.
# Folder with name 2024-03-17_032441 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_150358 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_063308 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_064053 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_064832 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_065618 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_070359 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_071148 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_071930 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_072715 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_025823 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_030559 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_031329 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_032102 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_032836 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_033607 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_034338 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_035113 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_035844 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_040617 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_041351 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_042128 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_042902 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_043637 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_073501 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_074243 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_075023 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_075807 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_080549 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_081332 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_082115 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_082900 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_083642 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_084420 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_085201 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_085945 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_090840 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_091810 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_092743 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_093713 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_094645 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_095623 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_100558 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_101530 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_102455 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_103423 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_104353 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_105323 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_044421 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_045154 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_045928 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_050701 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_051436 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_052212 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_052953 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_053741 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_054531 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_055311 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_060058 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_060838 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_061635 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_062436 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_011202 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_011942 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_012716 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_013449 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_014222 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_014956 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_015730 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_020508 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_021246 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_022021 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_022755 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_023534 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_024314 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_025052 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_110252 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_111145 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_112249 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_113142 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_114031 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_114918 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_115808 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_120702 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_121551 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_122439 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_123326 exists in renders_folder., 68 images found.
# Folder with name 2024-03-17_030129 exists in renders_folder., 68 images found.
# Folder with name 2024-03-17_030909 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_130156 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_131122 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_132051 exists in renders_folder., 68 images found.
# Folder with name 2024-03-18_230914 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_133728 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_134520 exists in renders_folder., 68 images found.
# Folder with name 2024-02-26_135311 exists in renders_folder., 68 images found.

# %%
psnrs, lpips_vals, ssims = [], [], []

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)


all_runs_metrics = {}

jsons_folder = "C:\Stuff\Results\jsons\jsons_ngp_stump_opt_off"
renders_folder = r"C:\Stuff\Results\renders\renders_stump_ngp_opt_off"
PATH_ORIGINAL_IMAGES = r"C:\Stuff\Results\originals\stump_original_images"

for filename in os.listdir(jsons_folder):
    if filename.endswith(".json"):
        json_filename = filename
        json_path = os.path.join(jsons_folder, filename)
        timestamp = get_timestamp(json_path)

        run_path = os.path.join(renders_folder, timestamp)
        print(run_path)
        if os.path.isdir(run_path):
            psnrs, lpips_vals, ssims = [], [], []

            for filename in os.listdir(run_path):
                if filename.endswith('img.jpg') and not filename.startswith('crop_degrated_') and not filename.startswith('lego'):
                    base_name = filename.split('-')[0]
                    degraded_filename = f'crop_degrated_{base_name}-img.jpg'
                    degraded_filepath = os.path.join(run_path, degraded_filename)

                    degraded_image = load_image(degraded_filepath)
                    original_image = load_image(os.path.join(PATH_ORIGINAL_IMAGES, base_name + '-img.jpg'))

                    original_image = original_image.unsqueeze(0)  # Add batch dimension
                    degraded_image = degraded_image.unsqueeze(0)  # Add batch dimension

                    psnr = psnr_metric(original_image, degraded_image)
                    ssim = ssim_metric(original_image, degraded_image)
                    lpips = lpips_metric(original_image, degraded_image)
                    psnrs.append(psnr.item())
                    ssims.append(ssim.item())
                    lpips_vals.append(lpips.item()) 
            # print(run_path)
            metrics = {
                'run': timestamp,
                'PSNR': psnrs,
                'SSIM': ssims,
                'LPIPS': lpips_vals
            }
            all_runs_metrics[json_filename[:-5]] = metrics
            
for run_metrics in all_runs_metrics:
    print(f"Metrics for run {run_metrics['run']}:")
    print(f"Name {run_metrics['name']}:")
    print("PSNR values:", run_metrics['PSNR'])
    print("SSIM values:", run_metrics['SSIM'])
    print("LPIPS values:", run_metrics['LPIPS'])
    print("\n")
# Out:
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-03-19_163127
# c:\Users\danko\miniconda3\envs\nerfstudio\lib\site-packages\torchmetrics\utilities\prints.py:70: FutureWarning: Importing `spectral_angle_mapper` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `spectral_angle_mapper` from `torchmetrics.image` instead.
#   _future_warning(
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_151315
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_152158
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_153050
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_153830
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_154719
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_155435
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_160152
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_140235
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_141207
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_142139
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-03-17_143415
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-03-17_142630
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_144506
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-03-17_032441
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_150358
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_063308
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_064053
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_064832
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_065618
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_070359
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_071148
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_071930
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_072715
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_025823
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_030559
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_031329
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_032102
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_032836
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_033607
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_034338
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_035113
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_035844
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_040617
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_041351
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_042128
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_042902
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_043637
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_073501
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_074243
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_075023
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_075807
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_080549
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_081332
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_082115
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_082900
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_083642
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_084420
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_085201
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_085945
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_090840
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_091810
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_092743
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_093713
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_094645
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_095623
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_100558
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_101530
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_102455
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_103423
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_104353
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_105323
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_044421
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_045154
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_045928
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_050701
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_051436
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_052212
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_052953
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_053741
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_054531
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_055311
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_060058
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_060838
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_061635
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_062436
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_011202
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_011942
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_012716
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_013449
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_014222
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_014956
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_015730
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_020508
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_021246
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_022021
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_022755
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_023534
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_024314
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_025052
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_110252
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_111145
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_112249
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_113142
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_114031
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_114918
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_115808
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_120702
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_121551
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_122439
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_123326
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-03-17_030129
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-03-17_030909
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_130156
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_131122
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_132051
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-03-18_230914
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_133728
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_134520
# C:\Stuff\Results\renders\renders_stump_ngp_opt_off\2024-02-26_135311
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 53
#      50             all_runs_metrics[json_filename[:-5]] = metrics
#      52 for run_metrics in all_runs_metrics:
# ---> 53     print(f"Metrics for run {run_metrics['run']}:")
#      54     print(f"Name {run_metrics['name']}:")
#      55     print("PSNR values:", run_metrics['PSNR'])
#
# TypeError: string indices must be integers

# %%
import numpy as np
import os

# Create the 'metrics' folder if it doesn't exist
folder_path = 'metrics'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Save the all_runs_metrics variable as an npy file
file_path = os.path.join(folder_path, 'ngp_stump_opt_off_metrics_new.npy')
np.save(file_path, all_runs_metrics)
