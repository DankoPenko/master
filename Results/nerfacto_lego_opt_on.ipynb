# %%
from torchmetrics.functional import structural_similarity_index_measure
from torchmetrics.image import PeakSignalNoiseRatio
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity
import re 
import json 
import os
from PIL import Image, ImageDraw, ImageFont
from torchvision.transforms import ToTensor
import numpy as np
import matplotlib.pyplot as plt 

types = ['benchmark', 'every', 'gamma', 'noise-std', 'orientation', 'blue-noise', 'green-noise', 'red-noise', 'pos-orient', 'position', 'range', 'saturation']
types_dict = {type: {} for type in types}

psnr_metric = PeakSignalNoiseRatio(data_range=1.0)
lpips_metric = LearnedPerceptualImagePatchSimilarity()
ssim_metric = structural_similarity_index_measure

def get_timestamp(path):
    f = open(path)
    data =  json.load(f)
    ckpt_path = data['checkpoint']
    pattern = r'\d{4}-\d{2}-\d{2}_\d{6}'
    match = re.search(pattern, ckpt_path)
    timestamp = match.group()
    return timestamp

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)

# %%
PATH_ORIGINAL_IMAGES = "C:\Stuff\Results\lego_original"
PATH_RENDERS = r"C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on"

for folder_path in os.listdir(PATH_RENDERS)[:]:
    for filename in os.listdir(os.path.join(PATH_RENDERS, folder_path)):
        if filename.lower().endswith('img.jpg') and 'crop' not in filename:
            file_path = os.path.join(PATH_RENDERS, folder_path, filename)
            original_image = Image.open(file_path)
            original_width, original_height = original_image.size
            left = original_width / 2  # Start from the middle of the image to get the right half
            top = 0  # Start from the top edge of the image
            right = original_width  # Extend to the right edge of the image
            bottom = original_height  # Extend to the bottom edge of the image
            cropped_image = original_image.crop((left, top, right, bottom))
            new_filename = f"crop_degrated_{filename}"
            new_file_path = os.path.join(PATH_RENDERS, folder_path, new_filename)
            cropped_image.save(new_file_path)
            original_image.close()

print("Cropping completed.")
# Out:
# Cropping completed.

# %%
import os
jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_lego_opt_on"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on"
renders_folde2 = r'C:\Stuff\Results\unknown_lego_renders'

for file in os.listdir(jsons_folder):
    if file.endswith('.json'):
        json_path = os.path.join(jsons_folder, file)
        timestamp = get_timestamp(json_path)
        run_path = os.path.join(renders_folder, timestamp)
        run_path2 = os.path.join(renders_folde2, timestamp)
        if os.path.isdir(run_path): #or os.path.isdir(run_path2):
            print(f"Folder with name {timestamp} exists in renders_folder., {len(os.listdir(run_path))} images found.")
        else:
            print(f"Folder with name {timestamp} does not exist in renders_folder.")
# Out:
# Folder with name 2024-03-10_014454 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_015014 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_015530 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_020047 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_020604 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_021121 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_021637 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_022154 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_022718 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_023243 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_023808 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_024333 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_024856 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_025421 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_025947 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_225210 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_225733 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_230257 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_230824 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_231349 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_231911 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_232436 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_233003 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_060019 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_061319 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_062605 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_063852 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_065138 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_070417 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_071700 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_072941 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_074208 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_075435 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_080708 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_081938 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_083203 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_084429 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_233527 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_234051 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_234615 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_235137 exists in renders_folder., 600 images found.
# Folder with name 2024-03-09_235701 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_000225 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_000749 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_001311 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_001835 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_002359 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_002922 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_003446 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_004008 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_004530 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_005053 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_005617 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_010140 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_010703 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_011229 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_011754 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_012318 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_012843 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_013406 exists in renders_folder., 600 images found.
# Folder with name 2024-03-10_013930 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_000944 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_002239 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_003531 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_004820 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_010114 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_011408 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_012657 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_013934 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_015210 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_020452 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_021724 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_022956 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_024235 exists in renders_folder., 600 images found.
# Folder with name 2024-03-17_025507 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_025638 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_030944 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_032251 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_033557 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_034902 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_040213 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_041518 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_042827 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_044136 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_045443 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_050749 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_052056 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_053405 exists in renders_folder., 600 images found.
# Folder with name 2024-03-03_054711 exists in renders_folder., 600 images found.
# Folder with name 2024-03-19_161206 exists in renders_folder., 600 images found.
# Folder with name 2024-03-18_032417 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_032942 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_033514 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_034041 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_034606 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_035121 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_035647 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_040203 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_040733 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_041254 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_022918 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_023444 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_024018 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_024554 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_025128 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_025654 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_030228 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_030802 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_031326 exists in renders_folder., 500 images found.
# Folder with name 2024-03-18_031852 exists in renders_folder., 500 images found.

# %%
psnrs, lpips_vals, ssims = [], [], []

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)


all_runs_metrics = {}

jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_lego_opt_on"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on"
PATH_ORIGINAL_IMAGES = r"C:\Stuff\Results\renders\lego_original_images"

for filename in os.listdir(jsons_folder):
    if filename.endswith(".json"):
        json_filename = filename
        json_path = os.path.join(jsons_folder, filename)
        timestamp = get_timestamp(json_path)

        run_path = os.path.join(renders_folder, timestamp)
        print(run_path)
        if os.path.isdir(run_path):
            psnrs, lpips_vals, ssims = [], [], []

            for filename in os.listdir(run_path):
                if filename.endswith('img.jpg') and not filename.startswith('crop_degrated_') and not filename.startswith('lego'):
                    base_name = filename.split('-')[0]
                    degraded_filename = f'crop_degrated_{base_name}-img.jpg'
                    degraded_filepath = os.path.join(run_path, degraded_filename)

                    degraded_image = load_image(degraded_filepath)
                    original_image = load_image(os.path.join(PATH_ORIGINAL_IMAGES, base_name + '-img.jpg'))

                    original_image = original_image.unsqueeze(0)  # Add batch dimension
                    degraded_image = degraded_image.unsqueeze(0)  # Add batch dimension

                    psnr = psnr_metric(original_image, degraded_image)
                    ssim = ssim_metric(original_image, degraded_image)
                    lpips = lpips_metric(original_image, degraded_image)
                    psnrs.append(psnr.item())
                    ssims.append(ssim.item())
                    lpips_vals.append(lpips.item()) 
            # print(run_path)
            metrics = {
                'run': timestamp,
                'PSNR': psnrs,
                'SSIM': ssims,
                'LPIPS': lpips_vals
            }
            all_runs_metrics[json_filename[:-5]] = metrics
            
for run_metrics in all_runs_metrics:
    print(f"Metrics for run {run_metrics['run']}:")
    print(f"Name {run_metrics['name']}:")
    print("PSNR values:", run_metrics['PSNR'])
    print("SSIM values:", run_metrics['SSIM'])
    print("LPIPS values:", run_metrics['LPIPS'])
    print("\n")
# Out:
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_014454
# c:\Users\danko\miniconda3\envs\nerfstudio\lib\site-packages\torchmetrics\utilities\prints.py:70: FutureWarning: Importing `spectral_angle_mapper` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `spectral_angle_mapper` from `torchmetrics.image` instead.
#   _future_warning(
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_015014
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_015530
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_020047
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_020604
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_021121
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_021637
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_022154
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_022718
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_023243
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_023808
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_024333
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_024856
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_025421
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_025947
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_225210
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_225733
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_230257
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_230824
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_231349
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_231911
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_232436
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_233003
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_060019
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_061319
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_062605
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_063852
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_065138
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_070417
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_071700
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_072941
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_074208
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_075435
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_080708
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_081938
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_083203
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_084429
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_233527
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_234051
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_234615
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_235137
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-09_235701
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_000225
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_000749
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_001311
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_001835
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_002359
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_002922
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_003446
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_004008
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_004530
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_005053
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_005617
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_010140
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_010703
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_011229
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_011754
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_012318
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_012843
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_013406
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-10_013930
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_000944
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_002239
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_003531
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_004820
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_010114
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_011408
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_012657
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_013934
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_015210
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_020452
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_021724
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_022956
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_024235
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-17_025507
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_025638
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_030944
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_032251
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_033557
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_034902
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_040213
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_041518
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_042827
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_044136
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_045443
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_050749
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_052056
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_053405
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-03_054711
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-19_161206
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_032417
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_032942
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_033514
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_034041
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_034606
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_035121
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_035647
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_040203
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_040733
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_041254
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_022918
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_023444
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_024018
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_024554
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_025128
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_025654
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_030228
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_030802
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_031326
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_on\2024-03-18_031852
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 53
#      50             all_runs_metrics[json_filename[:-5]] = metrics
#      52 for run_metrics in all_runs_metrics:
# ---> 53     print(f"Metrics for run {run_metrics['run']}:")
#      54     print(f"Name {run_metrics['name']}:")
#      55     print("PSNR values:", run_metrics['PSNR'])
#
# TypeError: string indices must be integers

# %%
import numpy as np
import os

# Create the 'metrics' folder if it doesn't exist
folder_path = 'metrics'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Save the all_runs_metrics variable as an npy file
file_path = os.path.join(folder_path, 'nerfacto_lego_opt_on_metrics.npy')
np.save(file_path, all_runs_metrics)
