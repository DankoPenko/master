# %%
from torchmetrics.functional import structural_similarity_index_measure
from torchmetrics.image import PeakSignalNoiseRatio
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity
import re 
import json 
import os
from PIL import Image, ImageDraw, ImageFont
from torchvision.transforms import ToTensor
import numpy as np
import matplotlib.pyplot as plt 

types = ['benchmark', 'every', 'gamma', 'noise-std', 'orientation', 'blue-noise', 'green-noise', 'red-noise', 'pos-orient', 'position', 'range', 'saturation']
types_dict = {type: {} for type in types}

psnr_metric = PeakSignalNoiseRatio(data_range=1.0)
lpips_metric = LearnedPerceptualImagePatchSimilarity()
ssim_metric = structural_similarity_index_measure

def get_timestamp(path):
    f = open(path)
    data =  json.load(f)
    ckpt_path = data['checkpoint']
    pattern = r'\d{4}-\d{2}-\d{2}_\d{6}'
    match = re.search(pattern, ckpt_path)
    timestamp = match.group()
    return timestamp

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)

# %%
PATH_ORIGINAL_IMAGES = "C:\Stuff\Results\lego_original"
PATH_RENDERS = r"C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off"

for folder_path in os.listdir(PATH_RENDERS)[:]:
    for filename in os.listdir(os.path.join(PATH_RENDERS, folder_path)):
        if filename.lower().endswith('img.jpg') and 'crop' not in filename:
            file_path = os.path.join(PATH_RENDERS, folder_path, filename)
            original_image = Image.open(file_path)
            original_width, original_height = original_image.size
            left = original_width / 2  # Start from the middle of the image to get the right half
            top = 0  # Start from the top edge of the image
            right = original_width  # Extend to the right edge of the image
            bottom = original_height  # Extend to the bottom edge of the image
            cropped_image = original_image.crop((left, top, right, bottom))
            new_filename = f"crop_degrated_{filename}"
            new_file_path = os.path.join(PATH_RENDERS, folder_path, new_filename)
            cropped_image.save(new_file_path)
            original_image.close()

print("Cropping completed.")
# Out:
# Cropping completed.

# %%
# import os
# jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_lego_opt_off"
# renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off"
# renders_folde2 = r'C:\Stuff\Results\unknown_lego_renders'

# for file in os.listdir(jsons_folder):
#     if file.endswith('.json'):
#         json_path = os.path.join(jsons_folder, file)
#         timestamp = get_timestamp(json_path)
#         run_path = os.path.join(renders_folder, timestamp)
#         run_path2 = os.path.join(renders_folde2, timestamp)
#         if os.path.isdir(run_path): #or os.path.isdir(run_path2):
#             print(f"Folder with name {timestamp} exists in renders_folder., {len(os.listdir(run_path))} images found.")
#         else:
#             print(f"Folder with name {timestamp} does not exist in renders_folder.")

# %%
psnrs, lpips_vals, ssims = [], [], []

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)


all_runs_metrics = {}

jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_lego_opt_off"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off"
PATH_ORIGINAL_IMAGES = r"C:\Stuff\Results\renders\lego_original_images"

for filename in os.listdir(jsons_folder):
    if filename.endswith(".json"):
        json_filename = filename
        json_path = os.path.join(jsons_folder, filename)
        timestamp = get_timestamp(json_path)

        run_path = os.path.join(renders_folder, timestamp)
        print(run_path)
        if os.path.isdir(run_path):
            psnrs, lpips_vals, ssims = [], [], []

            for filename in os.listdir(run_path):
                if filename.endswith('img.jpg') and not filename.startswith('crop_degrated_') and not filename.startswith('lego'):
                    base_name = filename.split('-')[0]
                    degraded_filename = f'crop_degrated_{base_name}-img.jpg'
                    degraded_filepath = os.path.join(run_path, degraded_filename)

                    degraded_image = load_image(degraded_filepath)
                    original_image = load_image(os.path.join(PATH_ORIGINAL_IMAGES, base_name + '-img.jpg'))

                    original_image = original_image.unsqueeze(0)  # Add batch dimension
                    degraded_image = degraded_image.unsqueeze(0)  # Add batch dimension

                    psnr = psnr_metric(original_image, degraded_image)
                    ssim = ssim_metric(original_image, degraded_image)
                    lpips = lpips_metric(original_image, degraded_image)
                    psnrs.append(psnr.item())
                    ssims.append(ssim.item())
                    lpips_vals.append(lpips.item()) 
            # print(run_path)
            metrics = {
                'run': timestamp,
                'PSNR': psnrs,
                'SSIM': ssims,
                'LPIPS': lpips_vals
            }
            all_runs_metrics[json_filename[:-5]] = metrics
            
for run_metrics in all_runs_metrics:
    print(f"Metrics for run {run_metrics['run']}:")
    print(f"Name {run_metrics['name']}:")
    print("PSNR values:", run_metrics['PSNR'])
    print("SSIM values:", run_metrics['SSIM'])
    print("LPIPS values:", run_metrics['LPIPS'])
    print("\n")
# Out:
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_131312
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_131844
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_132332
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_132913
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_133444
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_134017
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_134517
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_135000
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_135456
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_140056
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_140702
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_141322
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_141944
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_142511
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_143103
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_061424
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_061922
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_062418
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_062913
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_063408
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_063907
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_064405
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-02-19_064907
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_001247
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_002427
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_003604
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_004736
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_005906
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_011033
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_012201
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_013327
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_014452
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_015617
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_020741
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_021905
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_023028
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_024148
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_111348
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_112609
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_113759
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_114942
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_120126
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_121309
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_122448
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_123628
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_124808
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_125948
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_131124
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-24_173930
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-24_175302
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-24_180455
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_213015
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_214155
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_215332
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_220511
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_221651
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_222828
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_224004
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_225134
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_230315
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_231455
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_232631
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_233808
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-02_234940
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-03_000114
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-19_161800
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_004853
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_005423
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_005952
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_010531
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_011059
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_011638
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_012216
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_012752
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_013319
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_013847
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_014425
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_015000
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_015528
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_020057
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_020633
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_021200
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_021728
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_022255
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_022824
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_023401
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_023929
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_024459
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_025027
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-17_025554
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_014226
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_014703
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_015148
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_015632
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_020115
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_020552
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_021029
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_021514
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_021955
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_022436
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_005351
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_005838
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_010332
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_010825
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_011310
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_011803
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_012257
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_012752
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_013246
# C:\Stuff\Results\renders\renders_nerfacto_lego_opt_off\2024-03-18_013732
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 53
#      50             all_runs_metrics[json_filename[:-5]] = metrics
#      52 for run_metrics in all_runs_metrics:
# ---> 53     print(f"Metrics for run {run_metrics['run']}:")
#      54     print(f"Name {run_metrics['name']}:")
#      55     print("PSNR values:", run_metrics['PSNR'])
#
# TypeError: string indices must be integers

# %%
import numpy as np
import os

# Create the 'metrics' folder if it doesn't exist
folder_path = 'metrics'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Save the all_runs_metrics variable as an npy file
file_path = os.path.join(folder_path, 'nerfacto_lego_opt_off_metrics.npy')
np.save(file_path, all_runs_metrics)
