# %%
import os
from utils import get_title
def generate_latex_for_images(directory):
    # List all files in the provided directory
    image_files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    
    # LaTeX document header
    latex_document = r"""\documentclass{article}
\usepackage{graphicx}
\usepackage{caption}
\begin{document}
"""
    
    # Generate LaTeX code for each image file
    
    for image in image_files:
        if 'benchmark' not in image:
            # Escape underscores for LaTeX
            image_caption = image.replace('_', r'\_')
            # Build LaTeX figure code
            latex_figure = r"\begin{figure}[H]" + "\n" + \
                        r"\centering" + "\n" + \
                        r"\includegraphics[width=\linewidth]{images/plots_final/lego/" + image + "}" + "\n" + \
                        r"\caption{" + get_title(image_caption) + "}" + "\n" + \
                        r"\end{figure}" + "\n\n"
            latex_document += latex_figure
    
    # LaTeX document footer
    latex_document += r"\end{document}"
    
    return latex_document

# The directory containing the images
image_directory = r'C:\Stuff\Results\plots\lego_plots'  # Replace with your actual directory path

# Generate the LaTeX document
latex_code = generate_latex_for_images(image_directory)

# Print the generated LaTeX code
print(latex_code)
# Out:
# \documentclass{article}
# \usepackage{graphicx}
# \usepackage{caption}
# \begin{document}
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_blue-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for blue color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_every.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Reduced Image Set'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_gamma.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Gamma Correction'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_green-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for green color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_noise-std.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Image Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_orientation.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Orientation Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_pos-orient.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Combined Pose Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_position.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Positional Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_range.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Range'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_red-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for red color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/LPIPS_lego_saturation.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Saturation Change'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_blue-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for blue color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_every.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Reduced Image Set'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_gamma.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Gamma Correction'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_green-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for green color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_noise-std.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Image Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_orientation.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Orientation Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_pos-orient.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Combined Pose Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_position.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Positional Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_range.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Range'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_red-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for red color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/PSNR_lego_saturation.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Saturation Change'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_blue-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for blue color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_every.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Reduced Image Set'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_gamma.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Gamma Correction'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_green-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for green color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_noise-std.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Image Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_orientation.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Orientation Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_pos-orient.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Combined Pose Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_position.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Positional Noise'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_range.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Range'' experiment. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_red-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for red color. Lego dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/lego/SSIM_lego_saturation.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Saturation Change'' experiment. Lego dataset is used. }
# \end{figure}
#
# \end{document}

# %%
import os
from utils import get_title
def generate_latex_for_images(directory):
    # List all files in the provided directory
    image_files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    
    # LaTeX document header
    latex_document = r"""\documentclass{article}
\usepackage{graphicx}
\usepackage{caption}
\begin{document}
"""
    
    # Generate LaTeX code for each image file
    
    for image in image_files:
        if 'benchmark' not in image:
            # Escape underscores for LaTeX
            image_caption = image.replace('_', r'\_')
            # Build LaTeX figure code
            latex_figure = r"\begin{figure}[H]" + "\n" + \
                        r"\centering" + "\n" + \
                        r"\includegraphics[width=\linewidth]{images/plots_final/stump/" + image + "}" + "\n" + \
                        r"\caption{" + get_title(image_caption) + "}" + "\n" + \
                        r"\end{figure}" + "\n\n"
            latex_document += latex_figure
    
    # LaTeX document footer
    latex_document += r"\end{document}"
    
    return latex_document

# The directory containing the images
image_directory = r'C:\Stuff\Results\plots\stump_plots'  # Replace with your actual directory path

# Generate the LaTeX document
latex_code = generate_latex_for_images(image_directory)

# Print the generated LaTeX code
print(latex_code)
# Out:
# \documentclass{article}
# \usepackage{graphicx}
# \usepackage{caption}
# \begin{document}
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_blue-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for blue color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_every.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Reduced Image Set'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_gamma.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Gamma Correction'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_green-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for green color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_noise-std.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Image Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_orientation.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Orientation Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_pos-orient.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Combined Pose Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_position.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Positional Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_range.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Range'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_red-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for red color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/LPIPS_stump_saturation.pdf}
# \caption{Boxplot displaying the degradation results measured in LPIPS$\downarrow$ for the ``Saturation Change'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_blue-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for blue color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_every.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Reduced Image Set'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_gamma.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Gamma Correction'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_green-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for green color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_noise-std.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Image Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_orientation.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Orientation Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_pos-orient.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Combined Pose Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_position.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Positional Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_range.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Range'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_red-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for red color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/PSNR_stump_saturation.pdf}
# \caption{Boxplot displaying the degradation results measured in PSNR$\uparrow$ for the ``Saturation Change'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_blue-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for blue color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_every.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Reduced Image Set'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_gamma.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Gamma Correction'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_green-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for green color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_noise-std.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Image Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_orientation.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Orientation Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_pos-orient.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Combined Pose Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_position.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Positional Noise'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_range.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Range'' experiment. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_red-noise.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Channel-specific Image Pepper and Salt Noise'' experiment for red color. Stump dataset is used. }
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=\linewidth]{images/plots_final/stump/SSIM_stump_saturation.pdf}
# \caption{Boxplot displaying the degradation results measured in SSIM$\uparrow$ for the ``Saturation Change'' experiment. Stump dataset is used. }
# \end{figure}
#
# \end{document}
