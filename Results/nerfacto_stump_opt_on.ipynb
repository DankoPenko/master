# %%
from torchmetrics.functional import structural_similarity_index_measure
from torchmetrics.image import PeakSignalNoiseRatio
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity
import re 
import json 
import os
from PIL import Image, ImageDraw, ImageFont
from torchvision.transforms import ToTensor
import numpy as np
import matplotlib.pyplot as plt 

types = ['benchmark', 'every', 'gamma', 'noise-std', 'orientation', 'blue-noise', 'green-noise', 'red-noise', 'pos-orient', 'position', 'range', 'saturation']
types_dict = {type: {} for type in types}

psnr_metric = PeakSignalNoiseRatio(data_range=1.0)
lpips_metric = LearnedPerceptualImagePatchSimilarity()
ssim_metric = structural_similarity_index_measure

def get_timestamp(path):
    f = open(path)
    data =  json.load(f)
    ckpt_path = data['checkpoint']
    pattern = r'\d{4}-\d{2}-\d{2}_\d{6}'
    match = re.search(pattern, ckpt_path)
    timestamp = match.group()
    return timestamp

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)

# %%
PATH_ORIGINAL_IMAGES = "C:\Stuff\Results\stump_original"
PATH_RENDERS = r"C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on"

for folder_path in os.listdir(PATH_RENDERS)[:]:
    for filename in os.listdir(os.path.join(PATH_RENDERS, folder_path)):
        if filename.lower().endswith('img.jpg') and 'crop' not in filename:
            file_path = os.path.join(PATH_RENDERS, folder_path, filename)
            original_image = Image.open(file_path)
            original_width, original_height = original_image.size
            left = original_width / 2  # Start from the middle of the image to get the right half
            top = 0  # Start from the top edge of the image
            right = original_width  # Extend to the right edge of the image
            bottom = original_height  # Extend to the bottom edge of the image
            cropped_image = original_image.crop((left, top, right, bottom))
            new_filename = f"crop_degrated_{filename}"
            new_file_path = os.path.join(PATH_RENDERS, folder_path, new_filename)
            cropped_image.save(new_file_path)
            original_image.close()

print("Cropping completed.")
# Out:
# Cropping completed.

# %%
import os
jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_stump_opt_on"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on"
# renders_folde2 = r'C:\Stuff\Results\unknown_lego_renders'

for file in os.listdir(jsons_folder):
    if file.endswith('.json'):
        json_path = os.path.join(jsons_folder, file)
        timestamp = get_timestamp(json_path)
        run_path = os.path.join(renders_folder, timestamp)
        run_path2 = os.path.join(renders_folder, timestamp)
        if os.path.isdir(run_path): #or os.path.isdir(run_path2):
            print(f"Folder with name {timestamp} exists in renders_folder., {len(os.listdir(run_path))} images found.")
        else:
            print(f"Folder with name {timestamp} does not exist in renders_folder.")
# Out:
# Folder with name 2024-03-19_163855 exists in renders_folder., 102 images found.
# Folder with name 2024-03-31_141729 exists in renders_folder., 102 images found.
# Folder with name 2024-03-31_142639 exists in renders_folder., 102 images found.
# Folder with name 2024-03-31_143435 exists in renders_folder., 102 images found.
# Folder with name 2024-03-31_144232 exists in renders_folder., 102 images found.
# Folder with name 2024-03-31_145138 exists in renders_folder., 102 images found.
# Folder with name 2024-03-31_150025 exists in renders_folder., 102 images found.
# Folder with name 2024-03-31_150907 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_015101 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_015843 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_020612 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_021343 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_022112 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_022842 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_023613 exists in renders_folder., 102 images found.
# Folder with name 2024-01-14_024344 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_004804 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_005529 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_010257 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_011031 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_011759 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_012530 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_013257 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_014028 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_032831 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_033611 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_034352 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_035135 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_035921 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_040701 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_041439 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_042219 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_042956 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_043736 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_044528 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_045319 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_050115 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_050902 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_014759 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_015522 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_020245 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_021006 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_021729 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_022453 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_023220 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_023943 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_024703 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_025428 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_030150 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_030915 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_031640 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_032401 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_033125 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_033847 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_034607 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_035326 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_040048 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_040809 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_041531 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_042255 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_043020 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_043746 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_051656 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_052438 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_053228 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_054012 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_054805 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_055601 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_060351 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_061148 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_062013 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_062811 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_063556 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_064351 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_065138 exists in renders_folder., 153 images found.
# Folder with name 2024-01-07_065930 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_013945 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_014722 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_015507 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_020242 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_021029 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_021816 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_022606 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_023359 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_024140 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_024928 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_025712 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_030456 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_031249 exists in renders_folder., 102 images found.
# Folder with name 2024-01-07_032033 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_044519 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_045235 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_045948 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_050701 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_051411 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_052125 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_052835 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_053543 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_054254 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_055006 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_055714 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_060437 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_061159 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_061921 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_062641 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_063403 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_064123 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_064845 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_065607 exists in renders_folder., 102 images found.
# Folder with name 2024-01-08_070327 exists in renders_folder., 102 images found.

# %%
jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_stump_opt_on"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on"
PATH_ORIGINAL_IMAGES = r"C:\Stuff\Results\originals\stump_original_images"

for filename in os.listdir(jsons_folder):
    if filename.endswith(".json"):
        json_filename = filename
        json_path = os.path.join(jsons_folder, filename)
        timestamp = get_timestamp(json_path)

        run_path = os.path.join(renders_folder, timestamp)
        # print(run_path)
        if not os.path.exists(run_path):
            print(timestamp)
            os.listdir(run_path)

# %%
psnrs, lpips_vals, ssims = [], [], []

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)


all_runs_metrics = {}

jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_stump_opt_on"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on"
PATH_ORIGINAL_IMAGES = r"C:\Stuff\Results\originals\stump_original_images"

for filename in os.listdir(jsons_folder):
    if filename.endswith(".json"):
        json_filename = filename
        json_path = os.path.join(jsons_folder, filename)
        timestamp = get_timestamp(json_path)

        run_path = os.path.join(renders_folder, timestamp)
        print(run_path)
        if os.path.isdir(run_path):
            psnrs, lpips_vals, ssims = [], [], []

            for filename in os.listdir(run_path):
                if filename.endswith('img.jpg') and not filename.startswith('crop_degrated_') and not filename.startswith('lego') and not filename.startswith('full_rendered') and not filename.startswith('stump'):
                    base_name = filename.split('-')[0]
                    degraded_filename = f'crop_degrated_{base_name}-img.jpg'
                    degraded_filepath = os.path.join(run_path, degraded_filename)

                    degraded_image = load_image(degraded_filepath)
                    original_image = load_image(os.path.join(PATH_ORIGINAL_IMAGES, base_name + '-img.jpg'))

                    original_image = original_image.unsqueeze(0)  # Add batch dimension
                    degraded_image = degraded_image.unsqueeze(0)  # Add batch dimension

                    psnr = psnr_metric(original_image, degraded_image)
                    ssim = ssim_metric(original_image, degraded_image)
                    lpips = lpips_metric(original_image, degraded_image)
                    psnrs.append(psnr.item())
                    ssims.append(ssim.item())
                    lpips_vals.append(lpips.item()) 
            # print(run_path)
            metrics = {
                'run': timestamp,
                'PSNR': psnrs,
                'SSIM': ssims,
                'LPIPS': lpips_vals
            }
            all_runs_metrics[json_filename[:-5]] = metrics
# Out:
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-19_163855
# c:\Users\danko\miniconda3\envs\nerfstudio\lib\site-packages\torchmetrics\utilities\prints.py:70: FutureWarning: Importing `spectral_angle_mapper` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `spectral_angle_mapper` from `torchmetrics.image` instead.
#   _future_warning(
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-31_141729
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-31_142639
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-31_143435
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-31_144232
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-31_145138
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-31_150025
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-03-31_150907
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_015101
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_015843
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_020612
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_021343
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_022112
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_022842
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_023613
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-14_024344
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_004804
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_005529
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_010257
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_011031
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_011759
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_012530
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_013257
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_014028
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_032831
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_033611
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_034352
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_035135
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_035921
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_040701
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_041439
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_042219
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_042956
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_043736
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_044528
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_045319
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_050115
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_050902
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_014759
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_015522
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_020245
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_021006
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_021729
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_022453
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_023220
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_023943
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_024703
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_025428
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_030150
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_030915
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_031640
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_032401
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_033125
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_033847
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_034607
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_035326
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_040048
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_040809
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_041531
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_042255
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_043020
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_043746
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_051656
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_052438
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_053228
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_054012
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_054805
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_055601
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_060351
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_061148
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_062013
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_062811
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_063556
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_064351
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_065138
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_065930
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_013945
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_014722
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_015507
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_020242
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_021029
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_021816
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_022606
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_023359
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_024140
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_024928
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_025712
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_030456
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_031249
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-07_032033
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_044519
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_045235
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_045948
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_050701
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_051411
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_052125
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_052835
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_053543
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_054254
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_055006
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_055714
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_060437
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_061159
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_061921
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_062641
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_063403
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_064123
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_064845
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_065607
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_on\2024-01-08_070327

# %%
import numpy as np
import os

# Create the 'metrics' folder if it doesn't exist
folder_path = 'metrics'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Save the all_runs_metrics variable as an npy file
file_path = os.path.join(folder_path, 'nerfacto_stump_opt_on_metrics.npy')
np.save(file_path, all_runs_metrics)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
