# %%
from torchmetrics.functional import structural_similarity_index_measure
from torchmetrics.image import PeakSignalNoiseRatio
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity
import re 
import json 
import os
from PIL import Image, ImageDraw, ImageFont
from torchvision.transforms import ToTensor
import numpy as np
import matplotlib.pyplot as plt 

types = ['benchmark', 'every', 'gamma', 'noise-std', 'orientation', 'blue-noise', 'green-noise', 'red-noise', 'pos-orient', 'position', 'range', 'saturation']
types_dict = {type: {} for type in types}

psnr_metric = PeakSignalNoiseRatio(data_range=1.0)
lpips_metric = LearnedPerceptualImagePatchSimilarity()
ssim_metric = structural_similarity_index_measure

def get_timestamp(path):
    f = open(path)
    data =  json.load(f)
    ckpt_path = data['checkpoint']
    pattern = r'\d{4}-\d{2}-\d{2}_\d{6}'
    match = re.search(pattern, ckpt_path)
    timestamp = match.group()
    return timestamp

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)

# %%
PATH_ORIGINAL_IMAGES = "C:\Stuff\Results\stump_original"
PATH_RENDERS = r"C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off"

for folder_path in os.listdir(PATH_RENDERS)[:]:
    for filename in os.listdir(os.path.join(PATH_RENDERS, folder_path)):
        if filename.lower().endswith('img.jpg') and 'crop' not in filename:
            file_path = os.path.join(PATH_RENDERS, folder_path, filename)
            original_image = Image.open(file_path)
            original_width, original_height = original_image.size
            left = original_width / 2  # Start from the middle of the image to get the right half
            top = 0  # Start from the top edge of the image
            right = original_width  # Extend to the right edge of the image
            bottom = original_height  # Extend to the bottom edge of the image
            cropped_image = original_image.crop((left, top, right, bottom))
            new_filename = f"crop_degrated_{filename}"
            new_file_path = os.path.join(PATH_RENDERS, folder_path, new_filename)
            cropped_image.save(new_file_path)
            original_image.close()

print("Cropping completed.")
# Out:
# Cropping completed.

# %%
import os
jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_stump_opt_off"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off"
# renders_folde2 = r'C:\Stuff\Results\unknown_lego_renders'

for file in os.listdir(jsons_folder):
    if file.endswith('.json'):
        json_path = os.path.join(jsons_folder, file)
        timestamp = get_timestamp(json_path)
        run_path = os.path.join(renders_folder, timestamp)
        run_path2 = os.path.join(renders_folder, timestamp)
        if os.path.isdir(run_path): #or os.path.isdir(run_path2):
            print(f"Folder with name {timestamp} exists in renders_folder., {len(os.listdir(run_path))} images found.")
        else:
            print(f"Folder with name {timestamp} does not exist in renders_folder.")
# Out:
# Folder with name 2024-03-19_164609 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_115135 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_115848 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_120558 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_121253 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_121950 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_122656 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_123359 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_105436 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_110116 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_110746 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_111420 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_112133 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_112906 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_113645 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_114412 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_050632 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_051308 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_051956 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_052629 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_053305 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_053939 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_054616 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_055251 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_015726 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_020404 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_021045 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_021737 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_022430 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_023121 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_023816 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_024506 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_025145 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_025833 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_030522 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_031201 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_031839 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_032528 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_055928 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_060619 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_061252 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_061928 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_062615 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_063247 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_063934 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_064609 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_065245 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_065925 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_070613 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_071303 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_071954 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_072633 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_073312 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_074000 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_074645 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_075332 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_080017 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_080705 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_081339 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_082017 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_082656 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_083333 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_033206 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_033840 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_034531 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_035222 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_035916 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_040607 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_041258 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_041937 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_042629 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_043317 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_043952 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_044629 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_045305 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_045942 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_002102 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_002835 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_003553 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_004228 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_004914 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_005553 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_010250 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_010931 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_011623 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_012318 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_013012 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_013707 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_014404 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_015044 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_084006 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_084643 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_085317 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_085951 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_090625 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_091259 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_091921 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_092545 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_093218 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_093841 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_094519 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_095209 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_095843 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_100535 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_101224 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_101908 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_102543 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_103222 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_103939 exists in renders_folder., 102 images found.
# Folder with name 2024-03-07_104724 exists in renders_folder., 102 images found.

# %%
psnrs, lpips_vals, ssims = [], [], []

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return ToTensor()(image)


all_runs_metrics = {}

jsons_folder = "C:\Stuff\Results\jsons\jsons_nerfacto_stump_opt_off"
renders_folder = r"C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off"
PATH_ORIGINAL_IMAGES = r"C:\Stuff\Results\originals\stump_original_images"

for filename in os.listdir(jsons_folder):
    if filename.endswith(".json"):
        json_filename = filename
        json_path = os.path.join(jsons_folder, filename)
        timestamp = get_timestamp(json_path)

        run_path = os.path.join(renders_folder, timestamp)
        print(run_path)
        if os.path.isdir(run_path):
            psnrs, lpips_vals, ssims = [], [], []

            for filename in os.listdir(run_path):
                if filename.endswith('img.jpg') and not filename.startswith('crop_degrated_') and not filename.startswith('lego'):
                    base_name = filename.split('-')[0]
                    degraded_filename = f'crop_degrated_{base_name}-img.jpg'
                    degraded_filepath = os.path.join(run_path, degraded_filename)

                    degraded_image = load_image(degraded_filepath)
                    original_image = load_image(os.path.join(PATH_ORIGINAL_IMAGES, base_name + '-img.jpg'))

                    original_image = original_image.unsqueeze(0)  # Add batch dimension
                    degraded_image = degraded_image.unsqueeze(0)  # Add batch dimension

                    psnr = psnr_metric(original_image, degraded_image)
                    ssim = ssim_metric(original_image, degraded_image)
                    lpips = lpips_metric(original_image, degraded_image)
                    psnrs.append(psnr.item())
                    ssims.append(ssim.item())
                    lpips_vals.append(lpips.item()) 
            # print(run_path)
            metrics = {
                'run': timestamp,
                'PSNR': psnrs,
                'SSIM': ssims,
                'LPIPS': lpips_vals
            }
            all_runs_metrics[json_filename[:-5]] = metrics
            
for run_metrics in all_runs_metrics:
    print(f"Metrics for run {run_metrics['run']}:")
    print(f"Name {run_metrics['name']}:")
    print("PSNR values:", run_metrics['PSNR'])
    print("SSIM values:", run_metrics['SSIM'])
    print("LPIPS values:", run_metrics['LPIPS'])
    print("\n")
# Out:
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-19_164609
# c:\Users\danko\miniconda3\envs\nerfstudio\lib\site-packages\torchmetrics\utilities\prints.py:70: FutureWarning: Importing `spectral_angle_mapper` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `spectral_angle_mapper` from `torchmetrics.image` instead.
#   _future_warning(
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_115135
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_115848
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_120558
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_121253
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_121950
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_122656
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_123359
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_105436
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_110116
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_110746
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_111420
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_112133
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_112906
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_113645
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_114412
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_050632
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_051308
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_051956
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_052629
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_053305
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_053939
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_054616
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_055251
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_015726
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_020404
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_021045
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_021737
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_022430
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_023121
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_023816
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_024506
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_025145
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_025833
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_030522
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_031201
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_031839
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_032528
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_055928
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_060619
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_061252
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_061928
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_062615
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_063247
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_063934
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_064609
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_065245
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_065925
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_070613
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_071303
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_071954
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_072633
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_073312
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_074000
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_074645
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_075332
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_080017
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_080705
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_081339
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_082017
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_082656
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_083333
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_033206
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_033840
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_034531
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_035222
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_035916
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_040607
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_041258
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_041937
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_042629
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_043317
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_043952
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_044629
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_045305
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_045942
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_002102
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_002835
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_003553
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_004228
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_004914
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_005553
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_010250
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_010931
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_011623
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_012318
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_013012
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_013707
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_014404
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_015044
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_084006
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_084643
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_085317
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_085951
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_090625
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_091259
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_091921
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_092545
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_093218
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_093841
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_094519
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_095209
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_095843
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_100535
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_101224
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_101908
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_102543
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_103222
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_103939
# C:\Stuff\Results\renders\renders_nerfacto_stump_opt_off\2024-03-07_104724
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 53
#      50             all_runs_metrics[json_filename[:-5]] = metrics
#      52 for run_metrics in all_runs_metrics:
# ---> 53     print(f"Metrics for run {run_metrics['run']}:")
#      54     print(f"Name {run_metrics['name']}:")
#      55     print("PSNR values:", run_metrics['PSNR'])
#
# TypeError: string indices must be integers

# %%
import numpy as np
import os

# Create the 'metrics' folder if it doesn't exist
folder_path = 'metrics'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Save the all_runs_metrics variable as an npy file
file_path = os.path.join(folder_path, 'nerfacto_stump_opt_off_metrics.npy')
np.save(file_path, all_runs_metrics)
